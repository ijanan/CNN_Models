# %% [markdown]
# ## EfficientNet Implementation   - EfficientNet- B0

# %% [markdown]
# ### 1) Data Loading and Preprocessing

# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    ConfusionMatrixDisplay,
 )

DATASET_ROOT = r"F:\Durjoy_Work\Final_Dataset"
IMG_SIZE = 224
RANDOM_STATE = 415
BATCH_SIZE = 32
EPOCHS = 50

class_folders = sorted([
    d for d in os.listdir(DATASET_ROOT)
    if os.path.isdir(os.path.join(DATASET_ROOT, d))
])

print("Classes:", class_folders)
print("Number of classes:", len(class_folders))
# Out:
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Classes: ['Bacterial Leaf Blight', 'Brown Spot', 'Healthy Rice Leaf', 'Leaf Blast', 'Leaf scald', 'Sheath Blight']
# Number of classes: 6

# %%
records = []
images = []
labels = []

for label_name in class_folders:
    folder = os.path.join(DATASET_ROOT, label_name)
    for file_name in os.listdir(folder):
        image_path = os.path.join(folder, file_name)
        img = cv2.imread(image_path)
        if img is None:
            continue

        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images.append(img)
        labels.append(label_name)
        records.append((label_name, image_path))

images = np.array(images, dtype="float32")
labels = np.array(labels)

df = pd.DataFrame(records, columns=["label", "image_path"])
print("Total images:", len(images))
print(df.head())
# Out:
# Total images: 4264
#                    label                                         image_path
# 0  Bacterial Leaf Blight  F:\Durjoy_Work\Final_Dataset\Bacterial Leaf Bl...
# 1  Bacterial Leaf Blight  F:\Durjoy_Work\Final_Dataset\Bacterial Leaf Bl...
# 2  Bacterial Leaf Blight  F:\Durjoy_Work\Final_Dataset\Bacterial Leaf Bl...
# 3  Bacterial Leaf Blight  F:\Durjoy_Work\Final_Dataset\Bacterial Leaf Bl...
# 4  Bacterial Leaf Blight  F:\Durjoy_Work\Final_Dataset\Bacterial Leaf Bl...

# %%
class_names = sorted(np.unique(labels))
label_to_id = {name: idx for idx, name in enumerate(class_names)}
y = np.array([label_to_id[label] for label in labels], dtype=np.int32)

print("Class mapping:", label_to_id)
print("Label counts:")
print(df["label"].value_counts())
# Out:
# Class mapping: {'Bacterial Leaf Blight': 0, 'Brown Spot': 1, 'Healthy Rice Leaf': 2, 'Leaf Blast': 3, 'Leaf scald': 4, 'Sheath Blight': 5}
# Label counts:
# label
# Leaf Blast               836
# Brown Spot               791
# Bacterial Leaf Blight    729
# Leaf scald               718
# Healthy Rice Leaf        642
# Sheath Blight            548
# Name: count, dtype: int64

# %%
# 70/20/10 split: train/val/test
train_x, temp_x, train_y, temp_y = train_test_split(
    images, y, test_size=0.30, random_state=RANDOM_STATE, stratify=y
)

val_x, test_x, val_y, test_y = train_test_split(
    temp_x, temp_y, test_size=0.33, random_state=RANDOM_STATE, stratify=temp_y
)

print("Train:", train_x.shape, train_y.shape)
print("Val  :", val_x.shape, val_y.shape)
print("Test :", test_x.shape, test_y.shape)
# Out:
# Train: (2984, 224, 224, 3) (2984,)
# Val  : (857, 224, 224, 3) (857,)
# Test : (423, 224, 224, 3) (423,)

# %% [markdown]
# ### 2) EfficientNetB0 Model Training

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = len(class_names)

train_x_pp = tf.keras.applications.efficientnet.preprocess_input(train_x.copy())
val_x_pp = tf.keras.applications.efficientnet.preprocess_input(val_x.copy())
test_x_pp = tf.keras.applications.efficientnet.preprocess_input(test_x.copy())

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest",
)

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_tensor=inputs,
    pooling=None,
)
base_model.trainable = True

x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dropout(0.3)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

model = tf.keras.Model(inputs, outputs)
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
    verbose=1,
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1,
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1,
)

hist = model.fit(
    datagen.flow(train_x_pp, train_y, batch_size=BATCH_SIZE),
    steps_per_epoch=max(1, len(train_x_pp) // BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=(val_x_pp, val_y),
    callbacks=[early_stop, reduce_lr, checkpoint],
    verbose=1,
)

print("Training complete.")
# Out:
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 93/93 [==============================] - ETA: 0s - loss: 1.0606 - accuracy: 0.6016
# Epoch 1: val_accuracy improved from -inf to 0.64761, saving model to best_model.keras
# 93/93 [==============================] - 507s 5s/step - loss: 1.0606 - accuracy: 0.6016 - val_loss: 1.3726 - val_accuracy: 0.6476 - lr: 0.0010
# Epoch 2/50
# 93/93 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.7415
# Epoch 2: val_accuracy improved from 0.64761 to 0.74446, saving model to best_model.keras
# 93/93 [==============================] - 457s 5s/step - loss: 0.7187 - accuracy: 0.7415 - val_loss: 0.7599 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 3/50
# 93/93 [==============================] - ETA: 0s - loss: 0.6268 - accuracy: 0.7771
# Epoch 3: val_accuracy improved from 0.74446 to 0.78880, saving model to best_model.keras
# 93/93 [==============================] - 459s 5s/step - loss: 0.6268 - accuracy: 0.7771 - val_loss: 0.5928 - val_accuracy: 0.7888 - lr: 0.0010
# Epoch 4/50
# 93/93 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.8093
# Epoch 4: val_accuracy improved from 0.78880 to 0.84014, saving model to best_model.keras
# 93/93 [==============================] - 413s 4s/step - loss: 0.5254 - accuracy: 0.8093 - val_loss: 0.4500 - val_accuracy: 0.8401 - lr: 0.0010
# Epoch 5/50
# 93/93 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.8333
# Epoch 5: val_accuracy did not improve from 0.84014
# 93/93 [==============================] - 402s 4s/step - loss: 0.4922 - accuracy: 0.8333 - val_loss: 0.6419 - val_accuracy: 0.7993 - lr: 0.0010
# Epoch 6/50
# 93/93 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.8374
# Epoch 6: val_accuracy did not improve from 0.84014
# 93/93 [==============================] - 402s 4s/step - loss: 0.4675 - accuracy: 0.8374 - val_loss: 0.6568 - val_accuracy: 0.7573 - lr: 0.0010
# Epoch 7/50
# 93/93 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8384
# Epoch 7: val_accuracy did not improve from 0.84014
# 93/93 [==============================] - 403s 4s/step - loss: 0.4511 - accuracy: 0.8384 - val_loss: 0.5076 - val_accuracy: 0.8320 - lr: 0.0010
# Epoch 8/50
# 93/93 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.8550
# Epoch 8: val_accuracy did not improve from 0.84014
# 93/93 [==============================] - 394s 4s/step - loss: 0.4359 - accuracy: 0.8550 - val_loss: 0.5255 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 9/50
# 93/93 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8655
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.84014
# 93/93 [==============================] - 396s 4s/step - loss: 0.4122 - accuracy: 0.8655 - val_loss: 1.1139 - val_accuracy: 0.6523 - lr: 0.0010
# Epoch 10/50
# 93/93 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8862
# Epoch 10: val_accuracy improved from 0.84014 to 0.87981, saving model to best_model.keras
# 93/93 [==============================] - 402s 4s/step - loss: 0.3373 - accuracy: 0.8862 - val_loss: 0.3801 - val_accuracy: 0.8798 - lr: 5.0000e-04
# Epoch 11/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9075
# Epoch 11: val_accuracy improved from 0.87981 to 0.89148, saving model to best_model.keras
# 93/93 [==============================] - 401s 4s/step - loss: 0.2734 - accuracy: 0.9075 - val_loss: 0.3518 - val_accuracy: 0.8915 - lr: 5.0000e-04
# Epoch 12/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9082
# Epoch 12: val_accuracy improved from 0.89148 to 0.89848, saving model to best_model.keras
# 93/93 [==============================] - 513s 6s/step - loss: 0.2551 - accuracy: 0.9082 - val_loss: 0.3150 - val_accuracy: 0.8985 - lr: 5.0000e-04
# Epoch 13/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9085
# Epoch 13: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 400s 4s/step - loss: 0.2417 - accuracy: 0.9085 - val_loss: 0.3452 - val_accuracy: 0.8786 - lr: 5.0000e-04
# Epoch 14/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9170
# Epoch 14: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 401s 4s/step - loss: 0.2366 - accuracy: 0.9170 - val_loss: 0.3453 - val_accuracy: 0.8891 - lr: 5.0000e-04
# Epoch 15/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9289
# Epoch 15: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 405s 4s/step - loss: 0.2109 - accuracy: 0.9289 - val_loss: 0.4361 - val_accuracy: 0.8518 - lr: 5.0000e-04
# Epoch 16/50
# 93/93 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9302
# Epoch 16: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 387s 4s/step - loss: 0.2061 - accuracy: 0.9302 - val_loss: 0.3485 - val_accuracy: 0.8903 - lr: 5.0000e-04
# Epoch 17/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9302
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 17: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 391s 4s/step - loss: 0.1955 - accuracy: 0.9302 - val_loss: 0.3541 - val_accuracy: 0.8926 - lr: 5.0000e-04
# Epoch 18/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9424
# Epoch 18: val_accuracy did not improve from 0.89848
# 93/93 [==============================] - 390s 4s/step - loss: 0.1772 - accuracy: 0.9424 - val_loss: 0.3368 - val_accuracy: 0.8891 - lr: 2.5000e-04
# Epoch 19/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9451
# Epoch 19: val_accuracy improved from 0.89848 to 0.90432, saving model to best_model.keras
# 93/93 [==============================] - 411s 4s/step - loss: 0.1630 - accuracy: 0.9451 - val_loss: 0.2990 - val_accuracy: 0.9043 - lr: 2.5000e-04
# Epoch 20/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9516
# Epoch 20: val_accuracy did not improve from 0.90432
# 93/93 [==============================] - 436s 5s/step - loss: 0.1357 - accuracy: 0.9516 - val_loss: 0.3142 - val_accuracy: 0.9032 - lr: 2.5000e-04
# Epoch 21/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9472
# Epoch 21: val_accuracy did not improve from 0.90432
# 93/93 [==============================] - 444s 5s/step - loss: 0.1559 - accuracy: 0.9472 - val_loss: 0.3159 - val_accuracy: 0.9008 - lr: 2.5000e-04
# Epoch 22/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9563
# Epoch 22: val_accuracy improved from 0.90432 to 0.91365, saving model to best_model.keras
# 93/93 [==============================] - 441s 5s/step - loss: 0.1239 - accuracy: 0.9563 - val_loss: 0.3009 - val_accuracy: 0.9137 - lr: 2.5000e-04
# Epoch 23/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9529
# Epoch 23: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 451s 5s/step - loss: 0.1395 - accuracy: 0.9529 - val_loss: 0.3048 - val_accuracy: 0.9043 - lr: 2.5000e-04
# Epoch 24/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9553
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 24: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 425s 5s/step - loss: 0.1359 - accuracy: 0.9553 - val_loss: 0.3422 - val_accuracy: 0.8950 - lr: 2.5000e-04
# Epoch 25/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9668
# Epoch 25: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 389s 4s/step - loss: 0.1030 - accuracy: 0.9668 - val_loss: 0.2976 - val_accuracy: 0.9078 - lr: 1.2500e-04
# Epoch 26/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9617
# Epoch 26: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 393s 4s/step - loss: 0.1000 - accuracy: 0.9617 - val_loss: 0.3084 - val_accuracy: 0.8985 - lr: 1.2500e-04
# Epoch 27/50
# 93/93 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9668
# Epoch 27: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 383s 4s/step - loss: 0.1016 - accuracy: 0.9668 - val_loss: 0.2874 - val_accuracy: 0.9113 - lr: 1.2500e-04
# Epoch 28/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9699
# Epoch 28: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 380s 4s/step - loss: 0.0859 - accuracy: 0.9699 - val_loss: 0.3000 - val_accuracy: 0.9043 - lr: 1.2500e-04
# Epoch 29/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9678
# Epoch 29: val_accuracy did not improve from 0.91365
# 93/93 [==============================] - 384s 4s/step - loss: 0.0884 - accuracy: 0.9678 - val_loss: 0.3143 - val_accuracy: 0.9102 - lr: 1.2500e-04
# Epoch 30/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9712
# Epoch 30: val_accuracy improved from 0.91365 to 0.91715, saving model to best_model.keras
# 93/93 [==============================] - 386s 4s/step - loss: 0.0830 - accuracy: 0.9712 - val_loss: 0.2953 - val_accuracy: 0.9172 - lr: 1.2500e-04
# Epoch 31/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9685
# Epoch 31: val_accuracy did not improve from 0.91715
# 93/93 [==============================] - 385s 4s/step - loss: 0.0939 - accuracy: 0.9685 - val_loss: 0.2851 - val_accuracy: 0.9113 - lr: 1.2500e-04
# Epoch 32/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9736
# Epoch 32: val_accuracy did not improve from 0.91715
# 93/93 [==============================] - 384s 4s/step - loss: 0.0758 - accuracy: 0.9736 - val_loss: 0.2968 - val_accuracy: 0.9148 - lr: 1.2500e-04
# Epoch 33/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9780
# Epoch 33: val_accuracy improved from 0.91715 to 0.92065, saving model to best_model.keras
# 93/93 [==============================] - 384s 4s/step - loss: 0.0688 - accuracy: 0.9780 - val_loss: 0.3077 - val_accuracy: 0.9207 - lr: 1.2500e-04
# Epoch 34/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9695
# Epoch 34: val_accuracy did not improve from 0.92065
# 93/93 [==============================] - 385s 4s/step - loss: 0.0879 - accuracy: 0.9695 - val_loss: 0.3123 - val_accuracy: 0.9090 - lr: 1.2500e-04
# Epoch 35/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9729
# Epoch 35: val_accuracy did not improve from 0.92065
# 93/93 [==============================] - 380s 4s/step - loss: 0.0811 - accuracy: 0.9729 - val_loss: 0.3218 - val_accuracy: 0.9090 - lr: 1.2500e-04
# Epoch 36/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9665
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 36: val_accuracy did not improve from 0.92065
# 93/93 [==============================] - 386s 4s/step - loss: 0.0986 - accuracy: 0.9665 - val_loss: 0.3067 - val_accuracy: 0.9055 - lr: 1.2500e-04
# Epoch 37/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9726
# Epoch 37: val_accuracy did not improve from 0.92065
# 93/93 [==============================] - 385s 4s/step - loss: 0.0778 - accuracy: 0.9726 - val_loss: 0.2801 - val_accuracy: 0.9160 - lr: 6.2500e-05
# Epoch 38/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9746
# Epoch 38: val_accuracy did not improve from 0.92065
# 93/93 [==============================] - 385s 4s/step - loss: 0.0803 - accuracy: 0.9746 - val_loss: 0.2897 - val_accuracy: 0.9137 - lr: 6.2500e-05
# Epoch 39/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9817
# Epoch 39: val_accuracy improved from 0.92065 to 0.92182, saving model to best_model.keras
# 93/93 [==============================] - 386s 4s/step - loss: 0.0565 - accuracy: 0.9817 - val_loss: 0.2883 - val_accuracy: 0.9218 - lr: 6.2500e-05
# Epoch 40/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9790
# Epoch 40: val_accuracy did not improve from 0.92182
# 93/93 [==============================] - 384s 4s/step - loss: 0.0676 - accuracy: 0.9790 - val_loss: 0.2948 - val_accuracy: 0.9207 - lr: 6.2500e-05
# Epoch 41/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9807
# Epoch 41: val_accuracy improved from 0.92182 to 0.92415, saving model to best_model.keras
# 93/93 [==============================] - 405s 4s/step - loss: 0.0503 - accuracy: 0.9807 - val_loss: 0.2898 - val_accuracy: 0.9242 - lr: 6.2500e-05
# Epoch 42/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9800
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 42: val_accuracy did not improve from 0.92415
# 93/93 [==============================] - 396s 4s/step - loss: 0.0618 - accuracy: 0.9800 - val_loss: 0.3028 - val_accuracy: 0.9207 - lr: 6.2500e-05
# Epoch 43/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9800
# Epoch 43: val_accuracy did not improve from 0.92415
# 93/93 [==============================] - 383s 4s/step - loss: 0.0585 - accuracy: 0.9800 - val_loss: 0.2941 - val_accuracy: 0.9218 - lr: 3.1250e-05
# Epoch 44/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9776
# Epoch 44: val_accuracy did not improve from 0.92415
# 93/93 [==============================] - 384s 4s/step - loss: 0.0700 - accuracy: 0.9776 - val_loss: 0.2936 - val_accuracy: 0.9218 - lr: 3.1250e-05
# Epoch 45/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9807
# Epoch 45: val_accuracy improved from 0.92415 to 0.92532, saving model to best_model.keras
# 93/93 [==============================] - 385s 4s/step - loss: 0.0532 - accuracy: 0.9807 - val_loss: 0.2937 - val_accuracy: 0.9253 - lr: 3.1250e-05
# Epoch 46/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9804
# Epoch 46: val_accuracy did not improve from 0.92532
# 93/93 [==============================] - 397s 4s/step - loss: 0.0620 - accuracy: 0.9804 - val_loss: 0.2787 - val_accuracy: 0.9253 - lr: 3.1250e-05
# Epoch 47/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9851
# Epoch 47: val_accuracy did not improve from 0.92532
# 93/93 [==============================] - 416s 4s/step - loss: 0.0451 - accuracy: 0.9851 - val_loss: 0.2977 - val_accuracy: 0.9230 - lr: 3.1250e-05
# Epoch 48/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9834
# Epoch 48: val_accuracy did not improve from 0.92532
# 93/93 [==============================] - 390s 4s/step - loss: 0.0504 - accuracy: 0.9834 - val_loss: 0.2955 - val_accuracy: 0.9218 - lr: 3.1250e-05
# Epoch 49/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9831
# Epoch 49: val_accuracy did not improve from 0.92532
# 93/93 [==============================] - 388s 4s/step - loss: 0.0555 - accuracy: 0.9831 - val_loss: 0.3044 - val_accuracy: 0.9242 - lr: 3.1250e-05
# Epoch 50/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9827
# Epoch 50: val_accuracy did not improve from 0.92532
# 93/93 [==============================] - 392s 4s/step - loss: 0.0562 - accuracy: 0.9827 - val_loss: 0.3008 - val_accuracy: 0.9183 - lr: 3.1250e-05
# Training complete.

# %%
print("TRAINING SUMMARY")
print("-" * 50)
print(f"Final Train Accuracy: {hist.history['accuracy'][-1] * 100:.2f}%")
print(f"Final Val Accuracy:   {hist.history['val_accuracy'][-1] * 100:.2f}%")
print(f"Best Train Accuracy:  {max(hist.history['accuracy']) * 100:.2f}%")
print(f"Best Val Accuracy:    {max(hist.history['val_accuracy']) * 100:.2f}%")
# Out:
# TRAINING SUMMARY
# --------------------------------------------------
# Final Train Accuracy: 98.27%
# Final Val Accuracy:   91.83%
# Best Train Accuracy:  98.51%
# Best Val Accuracy:    92.53%

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plot training history
# ---------------------------
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 5))

# Training Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Train Accuracy', linewidth=2, color='blue')
plt.title('Training Accuracy', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

# Training Loss Plot
plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Train Loss', linewidth=2, color='blue')
plt.title('Training Loss', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# Predict on test set
test_pred = model.predict(test_x_pp, verbose=0)
test_pred_classes = np.argmax(test_pred, axis=1)

# Metrics
test_accuracy = accuracy_score(test_y, test_pred_classes)
test_precision = precision_score(test_y, test_pred_classes, average="weighted")
test_recall = recall_score(test_y, test_pred_classes, average="weighted")
test_f1 = f1_score(test_y, test_pred_classes, average="weighted")

print("TEST METRICS")
print("-" * 50)
print(f"Accuracy : {test_accuracy:.4f}")
print(f"Precision: {test_precision:.4f}")
print(f"Recall   : {test_recall:.4f}")
print(f"F1-score : {test_f1:.4f}")

# Keep labels in exact encoded order
ordered_class_names = [name for name, idx in sorted(label_to_id.items(), key=lambda x: x[1])]

print("\nClassification Report:")
print(classification_report(test_y, test_pred_classes, target_names=ordered_class_names))

# Confusion matrix
cm = confusion_matrix(test_y, test_pred_classes)

# Style similar to your shared figure
plt.figure(figsize=(14, 10))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=ordered_class_names,
    yticklabels=ordered_class_names,
    cbar_kws={"label": "Count"},
    annot_kws={"size": 12}
)

plt.title("Confusion Matrix - Test Data", fontsize=20, fontweight="bold")
plt.xlabel("Predicted Label", fontsize=17)
plt.ylabel("True Label", fontsize=17)
plt.xticks(rotation=0, fontsize=13)
plt.yticks(rotation=0, fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# TEST METRICS
# --------------------------------------------------
# Accuracy : 0.8960
# Precision: 0.8963
# Recall   : 0.8960
# F1-score : 0.8955
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# Bacterial Leaf Blight       0.92      0.99      0.95        72
#            Brown Spot       0.88      0.90      0.89        78
#     Healthy Rice Leaf       0.94      0.94      0.94        64
#            Leaf Blast       0.85      0.87      0.86        83
#            Leaf scald       0.87      0.81      0.83        72
#         Sheath Blight       0.96      0.89      0.92        54
#
#              accuracy                           0.90       423
#             macro avg       0.90      0.90      0.90       423
#          weighted avg       0.90      0.90      0.90       423

# %%
model.save("efficientnetb0.h5")
print("Saved model to efficientnetb0.h5")
# Out:
# c:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Saved model to efficientnetb0.h5

# %%
model.save("efficientnetb0.keras")
print("Saved model to efficientnetb0.keras")
# Out:
# Saved model to efficientnetb0.keras
